# %% [markdown]
# <a href="https://colab.research.google.com/github/MaximTislenko/Dawson_Python/blob/main/Sh_05_final_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Hero's Inventory 3.0.py

# %%
# Арсенал героя 3.0
# Демонстрирует работу со списками (lists)

# создадим список с несколькими элементами и выведем его с помощью цикла for
inventory = ['меч', 'кольчуга', 'щит', 'целебное снадобье']
print('Итак, в вашем арсенале:')
for item in inventory:
    print(item)

input('\nНажмите Enter, чтобы продолжить.\n')

# найдем длину списка
print('Сейчас в вашем рапоряжении', len(inventory), 'предмета/-ов.')

input('\nНажмите Enter, чтобы продолжить.\n')

# проверка на принадлежность к списку с помощью in
if 'целебное снадобье' in inventory:
    print('Вы ещё поживете и повоюете.')

# вывод одного элемента с определенным индексом
index = int(input('\nВведите индекс одного из предметов арсенала: '))
print('Под индексом', index, 'в асенале находится', inventory[index])

# отбразим срез
start = int(input('\nВведите начальный индекс среза: '))
finish = int(input('Введите конечный индекс среза: '))
print('Срез inventory [', start, ':', finish, '] - Это', end=' ')
print(inventory[start:finish])

input('\nНажмите Enter, чтобы продолжить.\n')

# соединим два списка
chest = ['золото', 'драгоценные камни']
print('\nВы нашли ларец. Вот что в нем лежит:')
print(chest)
print('Вы приобщили содержимое ларца к своему арсеналу.')
inventory += chest
print('Теперь в вашем распоряжении:')
print(inventory)

input('\nНажмите Enter, чтобы продолжить.\n')

# присваиваем значение элементу по индексу
print('Вы обменяли меч на арбалет.')
inventory[0] = 'арбалет'
print('Теперь ваш арсенал содержит следующие предметы:')
print(inventory)

input('\nНажмите Enter, чтобы продолжить.\n')

# присваиваем новое значение срезу индексов
print('За золото и драгоценные камни вы купили магический кристалл, способный предсказывать будущее.')
inventory[4:6] = ['магический кристалл']
print('Теперь в вашем распоряжении:')
print(inventory)

input('\nНажмите Enter, чтобы продолжить.\n')

# удаляем элемент
print('В тжелом бою был раздроблен ваш щит.')
del inventory[2]
print('Вот что осталось в арсенале:')
print(inventory)

input('\nНажмите Enter, чтобы продолжить.\n')

# удаляем срез
print('Воры лишили вас арбалета и кольчуги.')
del inventory[:2]
print('В арсенале теперь только:')
print(inventory)

input('\n\nНажмите Enter, чтобы выйти.')
# Out:
# Итак, в вашем арсенале:
# меч
# кольчуга
# щит
# целебное снадобье
#
# Нажмите Enter, чтобы продолжить.
#
# Сейчас в вашем рапоряжении 4 предмета/-ов.
#
# Нажмите Enter, чтобы продолжить.
#
# Вы ещё поживете и повоюете.
#
# Введите индекс одного из предметов арсенала: 0
# Под индексом 0 в асенале находится меч
#
# Введите начальный индекс среза: 0
# Введите конечный индекс среза: 5
# Срез inventory [ 0 : 5 ] - Это ['меч', 'кольчуга', 'щит', 'целебное снадобье']
#
# Нажмите Enter, чтобы продолжить.
#
#
# Вы нашли ларец. Вот что в нем лежит:
# ['золото', 'драгоценные камни']
# Вы приобщили содержимое ларца к своему арсеналу.
# Теперь в вашем распоряжении:
# ['меч', 'кольчуга', 'щит', 'целебное снадобье', 'золото', 'драгоценные камни']
#
# Нажмите Enter, чтобы продолжить.
#
# Вы обменяли меч на арбалет.
# Теперь ваш арсенал содержит следующие предметы:
# ['арбалет', 'кольчуга', 'щит', 'целебное снадобье', 'золото', 'драгоценные камни']
#
# Нажмите Enter, чтобы продолжить.
#
# ...

# %% [markdown]
# ## High Scores.py

# %%
# Рекорды
# Демонстрирует списочные методы

scores =[]

choice = None

while choice != "0":

    print(
        """
\tРекорды

\t0 - Выйти
\t1 - Показать рекорды
\t2 - Добавить рекорд
\t3 - Удалить рекорд
\t4 - Сортировать список
    """)
    choice = input("Ваш выбор: ")
    print()

    # выход
    if choice == "0":
        print("До свидания!")

    # Вывод лучших результатов на экран
    elif choice == "1":
        print("Рекорды:")
        for score in scores:
            print(score)

    # добавление рекорда
    elif choice == "2":
        score = int(input("Впишите свой рекорд: "))
        scores.append(score)

    # удаление рекорда
    elif choice == "3":
        score = int(input("Какой из рекордов удалить?: "))
        if score in scores:
            scores.remove(score)
        else:
            print("Результат ", score, " не содержится в списке рекордов .")

    # сортировка рекордов
    elif choice == "4":
        scores.sort(reverse=True)

    # непонятный пользовательский ввод
    else:
        print("Извините, в меню нет пункта", choice)

input('\n\nНажмите Enter, чтобы выйти.')

  # append(значение) - добавляет значение в конец списка
  # sort() - Сортирует элементы по возрастанию. Необязательный параметр reverse(если =True - то сортирует по убыванию)
  # reverse() - Обращает порядок элементов списка
  # count(значение) - Сообщает, сколько раз данное значение входит в список
  # index(значение) - Возвращает номер первой из позиции списка, которые заполнены данным значением
  # insert(i, значение) - Вставляет значение в позицию номер i
  # pop([i]) - Возвращает значение в позиции номер i и удаляет этот элемент из списка.
  #               Указывать число i необязательно. Если этот аргумент не передан,
  #                 возвращается и удаляется последний элемент списка.
  # remove(значение) - Удаляет первое вхождение данного значения в список.
# Out:
# 	Рекорды
#
# 	0 - Выйти
# 	1 - Показать рекорды
# 	2 - Добавить рекорд
# 	3 - Удалить рекорд
# 	4 - Сортировать список
#
# Ваш выбор: 1
#
# Рекорды:
#
# 	Рекорды
#
# 	0 - Выйти
# 	1 - Показать рекорды
# 	2 - Добавить рекорд
# 	3 - Удалить рекорд
# 	4 - Сортировать список
#
# Ваш выбор: 2
#
# Впишите свой рекорд: 10000
#
# 	Рекорды
#
# 	0 - Выйти
# 	1 - Показать рекорды
# 	2 - Добавить рекорд
# 	3 - Удалить рекорд
# 	4 - Сортировать список
#
# Ваш выбор: 2
#
# Впишите свой рекорд: 100
#
# 	Рекорды
#
# 	0 - Выйти
# 	1 - Показать рекорды
# 	2 - Добавить рекорд
# 	3 - Удалить рекорд
# 	4 - Сортировать список
#
# Ваш выбор: 2
#
# Впишите свой рекорд: 1000
#
# 	Рекорды
#
# 	0 - Выйти
# 	1 - Показать рекорды
# 	2 - Добавить рекорд
# 	3 - Удалить рекорд
# 	4 - Сортировать список
#
# Ваш выбор: 3
#
# Какой из рекордов удалить?: 150
# Результат  150  не содержится в списке рекордов .
#
# 	Рекорды
#
# 	0 - Выйти
# 	1 - Показать рекорды
# 	2 - Добавить рекорд
# 	3 - Удалить рекорд
# ...

# %%
scores
# Out:
# [10000, 1000]

# %% [markdown]
# ## High Scores 2.0.py

# %%
# Рекорды 2.0
# Демонстрирует вложенные последовательности

scores =[]

choice = None
while choice != "0":

    print("""
\tРекорды 2.0

\t0 - Выйти
\t1 - Показать рекорды
\t2 - Добавить рекорд
          """
          )
    choice = input("\nВаш выбор: ")
    print()

    # выход
    if choice == "0":
        print("До свидания!")

    # вывод таблицы рекордов
    elif choice == "1":
        print("Рекорды:")
        print("ИМЯ\tРЕЗУЛЬТАТ")
        for entry in scores:
            score, name = entry
            print(name, "\t", score)

    # добавление результата
    elif choice == "2":
        name = input("Введите имя игрока: ")
        score = int(input("Впишите его результат: "))
        entry = (score, name)
        scores.append(entry)
        scores.sort(reverse=True)
        scores = scores[:5]   # В списке остается только 5 рекордов

    # непонятный пользовательский ввод
    else:
        print("Извените, в меню нет пункта", choice)

input('\n\nНажмите Enter, чтобы выйти.')
# Out:
# 	Рекорды 2.0
#
# 	0 - Выйти
# 	1 - Показать рекорды
# 	2 - Добавить рекорд
#
#
# Ваш выбор: 1
#
# Рекорды:
# ИМЯ	РЕЗУЛЬТАТ
#
# 	Рекорды 2.0
#
# 	0 - Выйти
# 	1 - Показать рекорды
# 	2 - Добавить рекорд
#
#
# Ваш выбор: 2
#
# Введите имя игрока: Максим
# Впишите его результат: 100000
#
# 	Рекорды 2.0
#
# 	0 - Выйти
# 	1 - Показать рекорды
# 	2 - Добавить рекорд
#
#
# Ваш выбор: 2
#
# Введите имя игрока: Вася
# Впишите его результат: 100
#
# 	Рекорды 2.0
#
# 	0 - Выйти
# 	1 - Показать рекорды
# 	2 - Добавить рекорд
#
#
# Ваш выбор: 2
#
# Введите имя игрока: Марина
# Впишите его результат: 10000
#
# 	Рекорды 2.0
#
# 	0 - Выйти
# 	1 - Показать рекорды
# 	2 - Добавить рекорд
#
#
# Ваш выбор: 2
#
# Введите имя игрока: Владимир
# Впишите его результат: 1500
#
# 	Рекорды 2.0
#
# 	0 - Выйти
# 	1 - Показать рекорды
# 	2 - Добавить рекорд
#
#
# Ваш выбор: 1
#
# Рекорды:
# ИМЯ	РЕЗУЛЬТАТ
# Максим 	 100000
# Марина 	 10000
# Владимир 	 1500
# Вася 	 100
#
# 	Рекорды 2.0
#
# 	0 - Выйти
# ...

# %% [markdown]
# ## Geek Translator.py

# %%
# Переводчик с гикского на русский
# Вумонстрирует использование словарей (dictionaries)

geek = {"404": "Не знать, не владеть информацией. От сообщения об ошибке 'страница не найдена'.",
        "Googling": "'Гугление', поиск в Сети сведений о ком-либо.",
        "Keyboard Plaque": "Мусор, который скапливается в клавиатуре компьютера.",
        "Link Rot": "Процесс устаревания гиперссылок на веб страницах.",
        "Percussive Maintenance": "О ситуации, когда кто-либо бьет по корпусу неисправного электронного прибора в надежде восстановить его работу.",
        "Uninstalled": "Об увольнении кого либо. Особенно популярно на рубеже 1990 - 2000-х годов."}

choice = None
while choice != "0":

    print(
        """
Переводчик с гикского на русский

0 - Выйти
1 - Найти толкование термина
2 - Добавить термин
3 - Изменить толкование
4 - Удалить термин
"""
        )
    choice = input("Выш выбор: ")
    print()

    # выход
    if choice == "0":
        print("До свидания!")

    # поиск толкования
    elif choice == "1":
        term = input("Какой термин вы хотите перевести с гикского на русский? ")
        if term in geek:
            definition = geek[term]
            print("\n", term, "означает", definition)
        else:
            print("\nУвы, этот термин мне незнаком", term)

    # добавление термина с толкованием
    elif choice == "2":
        term = input("Какой термин гикского языка вы хотите добавить?: ")
        if term not in geek:
            definition = input("Впишите ваше толкование?: ")
            geek[term] = definition
            print("\nТермин ", term, " добавлен в словарь.")
        else:
            print("\nТакой термин уже есть! Попробуйте изменить его толкование.")
            geek[term] = definition

    # новое толкование известного термина
    elif choice == "3":
        term = input("Какой термин выхотите переопределить?: ")
        if term in geek:
            definition = input("Впишите ваше толкование?: ")
            geek[term] = definition
            print("\nТермин ", term, " переопределен.")
        else:
            print("Такого термина пока нет. Попробуйте добавить его в словарь.")

    # удаление термина вместе с его толкованием
    elif choice == "4":
        term = input("Какой термин вы хотите удалить? ")
        if term in geek:
            del geek[term]
            print("\nТермин ", term, " удален")
        else:
            print("\nНичем не могу помочь. Термина ", term, " нет в словаре.")

    # непонятный пользовательский ввод
    else:
        print("\nИзвените, с меню нет пункта ", choice)

input('\n\nНажмите Enter, чтобы выйти.')


# get(ключ,[умолчание]) - Возвращает значение по ключу. Если ключ не определен в словаре, то возвращается умолчание.
#                         Если, в свою очередь, умолчание не задано, возвращается None
# keys() - Возвращает набор всех ключей словаря
# values() - Возвращает набор всех значений словаря
# items() - Возвращает набор всех пар в словаре. Каждая пара представляет собой кортеж из двух элементов:
#           первый  - ключ, второй - соответствующее значение.
# Out:
# Переводчик с гикского на русский
#
# 0 - Выйти
# 1 - Найти толкование термина
# 2 - Добавить термин
# 3 - Изменить толкование
# 4 - Удалить термин
#
# Выш выбор: 1
#
# Какой термин вы хотите перевести с гикского на русский? 404
#
#  404 означает Не знать, не владеть информацией. От сообщения об ошибке 'страница не найдена'.
#
# Переводчик с гикского на русский
#
# 0 - Выйти
# 1 - Найти толкование термина
# 2 - Добавить термин
# 3 - Изменить толкование
# 4 - Удалить термин
#
# Выш выбор: 4
#
# Какой термин вы хотите удалить? 0
#
# Ничем не могу помочь. Термина  0  нет в словаре.
#
# Переводчик с гикского на русский
#
# 0 - Выйти
# 1 - Найти толкование термина
# 2 - Добавить термин
# 3 - Изменить толкование
# 4 - Удалить термин
#
# Выш выбор:
#
#
# Извените, с меню нет пункта
#
# Переводчик с гикского на русский
#
# 0 - Выйти
# 1 - Найти толкование термина
# 2 - Добавить термин
# 3 - Изменить толкование
# 4 - Удалить термин
#
# Выш выбор:
#
#
# Извените, с меню нет пункта
#
# ...

# %% [markdown]
# ## Hangman.py

# %%
# Виселица
#
# Классическая игра "Виселица". Компьютер случайным образом выбирает слово,
# которое игрок должен отгадать буква за буквой. Если игрок не сумеет
# отгадать за отведенное количесство попыток, на экране появится фигурка повешенного.

# импорт модуля
import random

# константа (картинки)
HANGMAN = ("""


|\
|_\_____""","""
|
|
|
|
|
|
|
|\
|_\_____""","""
------.
|     |
|
|
|
|
|
|
|\
|_\_____""","""
------.
|     |
|     O
|
|
|
|
|
|\
|_\_____""","""
------.
|     |
|     O
|    /|\\
|
|
|
|
|\
|_\_____""","""
------.
|     |
|     O
|    /|\\
|    |||
|
|
|
|\
|_\_____""","""
------.
|     |
|     O
|    /|\\
|    |||
|     |
|
|
|\
|_\_____""","""
------.
|     |
|     O
|    /|\\
|    |||
|     |
|    | |
|    | |
|\
|_\_____
""")

MAX_WRONG = len(HANGMAN) - 1

WORDS = ["КИТ", "РЕВОЛЮЦИЯ", "ПЕДИАТР", "НОВОРОЖДЕННЫЙ", "ПУПОК"]

# инициализация переменных
word = random.choice(WORDS) # слово для отгадывания
print(word)

so_far = "-" * len(word)    # по одному дефису на каждую букву, которую надо отгадать
wrong = 0                   # количество ошибок, которые сделал игрок
used = []                   # буквы, которые игрок уже предлагал

print('Добро пожаловать в игру "Виселица". Удачи вам!')

while wrong < MAX_WRONG and so_far != word:
    print(HANGMAN[wrong])
    print("\nВы уже предлагали следующие буквы:\n", used)
    print("\nОтгаданные вами буквы в слове сейчас выглядат так:\n", so_far)

    guess = input("\n\nВведите букву: ")
    guess = guess.upper()

    while guess in used:
        print("Вы уже предлагали букву", guess)
        guess = input("Введите букву: ")
        guess = guess.upper()

    used.append(guess)

    if guess in word:
        print("\nДа! Буква ", guess, "Есть в слове!")

        # новая строка so_far с отгаданной буквой или буквами
        new = ""
        for i in range(len(word)):
            if guess == word[i]:
                new += guess
            else:
                new += so_far[i]
        so_far = new

    else:
        print("\nК сожалению, буквы ,", guess, "нет в слове.")
        wrong += 1

if wrong == MAX_WRONG:
    print(HANGMAN[wrong])
    print("\nВас повесили!")
else:
    print("\nВы отгадали!")

print("\nБыло загадано слово", word)

input('\n\nНажмите Enter, чтобы выйти.')
# Out:
# КИТ
# Добро пожаловать в игру "Виселица". Удачи вам!
#
#
#
# ||_\_____
#
# Вы уже предлагали следующие буквы:
#  []
#
# Отгаданные вами буквы в слове сейчас выглядат так:
#  ---
#
#
# Введите букву: о
#
# К сожалению, буквы , О нет в слове.
#
# |
# |
# |
# |
# |
# |
# |
# ||_\_____
#
# Вы уже предлагали следующие буквы:
#  ['О']
#
# Отгаданные вами буквы в слове сейчас выглядат так:
#  ---
#
#
# Введите букву: к
#
# Да! Буква  К Есть в слове!
#
# |
# |
# |
# |
# |
# |
# |
# ||_\_____
#
# Вы уже предлагали следующие буквы:
#  ['О', 'К']
#
# Отгаданные вами буквы в слове сейчас выглядат так:
#  К--
#
#
# Введите букву: р
#
# К сожалению, буквы , Р нет в слове.
#
# ------.
# |     |
# |
# |
# |
# |
# |
# |
# ||_\_____
#
# Вы уже предлагали следующие буквы:
#  ['О', 'К', 'Р']
#
# Отгаданные вами буквы в слове сейчас выглядат так:
#  К--
#
#
# Введите букву: т
#
# Да! Буква  Т Есть в слове!
#
# ------.
# |     |
# |
# |
# |
# |
# |
# |
# ||_\_____
#
# Вы уже предлагали следующие буквы:
# ...

# %% [markdown]
# ## Задачи

# %% [markdown]
# ### Задача №1

# %%
# Глава 5, Испытание 1

# Создайте программу, которая печатает список слов в случайном порядке.
# Программа должна печатать все слова и не повторять их.

import random
words = ['word1', 'word2', 'hate', 'bronchitis', 'blue']

for i in range(len(words)):
    word = random.choice(words)
    print(word)
    words.remove(word)

input('\n\nНажмите Enter, чтобы выйти.')
# Out:
# bronchitis
# blue
# word1
# hate
# word2
#
#
# Нажмите Enter, чтобы выйти.
# ''

# %% [markdown]
# ### Задача №2

# %%
# Глава 5, Испытание 2
# Напишите программу создания персонажей для ролевой игры.
# Игроку должен быть предоставлен пул из 30 очков, которые он может потратить на четыре атрибута:
     # Сила, здоровье, мудрость и ловкость
# Игрок должен иметь возможность тратить очки из пула на любой атрибут
# а также иметь возможность снимать очки с атрибута и возвращать их обратно
# В пул.

print("""
            ПРОГРАММА СОЗДАНИЯ ПЕРСОНАЖЕЙ

У вас есть 30 очков в пуле, которые вы можете потратить на атрибуты по своему желанию:
     Сила, Здоровье, Мудрость, Ловкость.
Если вы захотите, вы можете затем снять очки с атрибута и вернуть их обратно в пул.

"""
      )

attributes = {'Сила':0, 'Здоровье':0, 'Мудрость':0, 'Ловкость':0}
pool = 30
spend  = None
choice = None

choice_sentence = """
\n\nЧем бы Вы хотели заняться?
0 - Выход
1 - Потратьте баллы на атрибут
2 - Положите очки в пул
"""

attribute_list = """\tСила
\tЗдоровье
\tМудрость
\tЛовкость
"""

while choice != "0":
    print("\nВаш персонаж имеет следующие атрибуты:")
    for attribute, points in attributes.items():
        print("\t",attribute.title(), ":  \t ", points, sep = "")
    print("\nВ пуле ", pool, " очков.", sep="")
    print(choice_sentence)
    choice = input("Выбор: ")
    while choice != "0" and choice != "1" and choice != "2":
        print("Неверный выбор")
        print(choice_sentence)
        choice = input("Выбор: ")
    while choice == "1": # потратить баллы на атрибут
        if pool == 0: # нет баллов, которые можно потратить
            print("Извините, у вас недостаточно баллов. Попробуйте вернуть несколько баллов в пулл")

            break
        print("\nУ вас есть ", pool, " очков в пуле.", sep="")
        print("\nК какому атрибуту вы хотите добавить?")
        print(attribute_list)
        att_to_change = input("Выберите атрибут: ")
        while (att_to_change.title() != "Сила" and
            att_to_change.title() != "Здоровье" and
            att_to_change.title() != "Мудрость" and
            att_to_change.title() != "Ловкость"):
            print("Это неправильный выбор.")
            print("К какому атрибуту вы хотите добавить?")
            print(attribute_list)
            att_to_change = input("Атрибут для изменения: ")
        else:
            points = int(input("Сколько баллов вы хотели бы потратить?: "))
            while points > pool:
                print("Это слишком много очков. У вас есть", pool, "очков")
                points = int(input("Сколько баллов вы хотели бы потратить?: "))
        attributes[att_to_change] += points
        pool -= points
        print("\nВаши атрибуты")
        for attribute, points in attributes.items():
            print("\t", attribute.title(), ":  \t", points, sep="")
        if pool == 0:
            print("\nВы потратили все свои баллы.")
            choice = None
            break
        another_change = input("Хотите изменить другой атрибут? Да или Нет: ")
        while another_change.title() != "Да" and another_change.title() != "Нет":
            print("Это неверный выбор.")
            another_change = input("Хотите изменить другой атрибут? Да или Нет: ")
        if another_change.title() == "No":
            break

    while choice == "2": # добавить очки в пул
        if pool == 30: # пул уже полон
            print("\nИзвините, у вас нет очков в ваших атрибутах."
                  "\nПопробуйте сначала добавить несколько очков к своим атрибутам..")
            break
        print("\nИз какого атрибута вы хотели бы снять баллы?")
        for attribute, points in attributes.items():
            print(attribute.title(), ":\t", points, sep="")
        att_to_change = input("Выбор: ")
        while (att_to_change.title() != "Сила" and
        att_to_change.title() != "Здоровье" and
        att_to_change.title() != "Мудрость" and
        att_to_change.title() != "Ловкость"):
            print("\nЭто неправильный выбор.")
            print("\nИз какого атрибута вы хотели бы снять баллы?")
            for attribute, points in attributes.items():
                print(attribute.title(), ":\t", points, sep="")
            att_to_change = input("Выбор: ")
        while attributes[att_to_change] == 0:
            # никакие баллы не могут быть удалены
            print("У вас нет баллов по этому атрибуту.")
            att_to_change = input("Выбор: ")
            while (att_to_change.title() != "Сила" and
        att_to_change.title() != "Здоровье" and
        att_to_change.title() != "Мудрость" and
        att_to_change.title() != "Ловкость"):
                print("Это неправильный выбор.")
                print("Из какого атрибута вы хотели бы снять баллы?")
                att_to_change = input("Выбор: ")
        points = int(input("\nСколько баллов вы хотите удалить?: "))
        while points > attributes[att_to_change]:
            # недостаточно очков в атрибуте
            print("Извините, это слишком много баллов! У вас есть только",
                  attributes[att_to_change], " в ", att_to_change)
            points = int(input("\nСколько пунктов вы хотели бы удалить?: "))
        print("OK!")
        pool += points
        attributes[att_to_change] -= points
        print("Теперь у вас есть ", pool, " баллов в пуле.", sep="")
        another_change = input("\nХотите изменить другой атрибут? Да или Нет: ")
        while another_change.title() != "Да" and another_change.title() != "Нет":
            print("Это неверный выбор.")
            another_change = input("Хотите изменить другой атрибут? Да или Нет: ")
        if another_change.title() == "Нет":
            break

print("До свидания!")

input('\n\nНажмите Enter, чтобы выйти.')

# %%
print(pool, att_to_change )
# Out:
# 10 Сила

# %% [markdown]
# ### Задача №3

# %%
# Глава 5, Испытание 3

# Напиши «Кто твой папа?» программа, позволяющая пользователю вводить имя мужчины
# и выдаёт имя своего отца. Разрешить пользователю добавлять, заменять и
# удалить пары сын-отец.

sf = {'том круз':'энтони хопкинс', 'борис беккер':'тин тин'}
son = ''
father = ''
choice = None

while choice != "0":
    print("""\n\nВы хотите:

0 - Выйти
1 - Посмотреть пары Сын-Отец
2 - Добавьте пару Сын-Отец
3 - Заменить пару Сын-Отец
4 - Удалить пару Сын-Отец
""")
    choice = input("Какой вариант вы бы хотели выбрать? ")
    if choice == "1":
        if sf == {}:
            print("База данных сейчас пуста, почему бы вам не добавить ее!")
            continue
        else:
            for son, father in sf.items():
                print(son.title(), "является сыном", father.title())
    elif choice == "2":
        son = input("Кто сын? ")
        son = son.lower()
        if son in sf:
            print("Этот сын уже существует! Попробуйте вместо этого заменить сына.")
            continue
        father = input("Кто отец? ")
        father = father.lower()
        sf[son] = father
        print("\n", son.title(), "является сыном", father.title())
    elif choice == "3":
        sorf = input("Знаешь ли ты сына или отца?: ")
        sorf = sorf.lower()
        while sorf != "сына" and sorf != "отца":
            print("Извините, пожалуйста, напишите 'сына' или 'отца'.")
            sorf = input("Знаешь ли ты сына или отца?: ")
            sorf = sorf.lower()
        if sorf == "сына":
            son = input("Кто сын? ")
            son = son.lower()
            if son in sf.keys():
                print("Нынешний отец", sf[son].title())
                father = input("Кем бы вы хотели его заменить?: ")
                father = father.lower()
                sf[son] = father
                print("Отец этого человека", son.title(), "сейчас", father.title())
            elif son not in sf.keys():
                print("Того сына не существует. Почему бы тебе не попробовать добавить его?")
                continue
        if sorf == "отца":
            father = input("Кто отец? ")
            father = father.lower()
            if father in sf.values():
                for son, dad in sf.items(): # найти правильного отца в sf
                    if dad == father:
                        print("Нынешний сын", son.title())
                        del sf[son]
                        son = input("Кем бы вы хотели его заменить??: ")
                        sf[son] = father
                        print(son.title(), " сын ", father.title())
                        break
            elif father not in sf.values():
                print(father, "не существует. Почему бы тебе не попробовать добавить его?")
    elif choice == "4":
        son = input("Кто такой сын? ")
        son = son.lower()
        if son not in sf:
            print(son, "не существует! Возможно, вы их уже удалили.")
            continue
        else:
            print(son.title(), "и", sf[son].title(), "были удалены.")
            del sf[son]
    else:
        print("Извините, это неправильный выбор.")

print("\nСпасибо за игру!")
input('\n\nНажмите Enter, чтобы выйти.')
# Out:
# Вы хотите:
#
# 0 - Выйти
# 1 - Посмотреть пары Сын-Отец
# 2 - Добавьте пару Сын-Отец
# 3 - Заменить пару Сын-Отец
# 4 - Удалить пару Сын-Отец
#
# Какой вариант вы бы хотели выбрать? 1
# Том Круз является сыном Энтони Хопкинс
# Борис Беккер является сыном Тин Тин
#
#
# Вы хотите:
#
# 0 - Выйти
# 1 - Посмотреть пары Сын-Отец
# 2 - Добавьте пару Сын-Отец
# 3 - Заменить пару Сын-Отец
# 4 - Удалить пару Сын-Отец
#
# Какой вариант вы бы хотели выбрать? 0
# Извините, это неправильный выбор.
#
# Спасибо за игру!
#
#
# Нажмите Enter, чтобы выйти.
# ''

# %% [markdown]
# ### Задача №4

# %%
# Глава 5, Испытание 4

# Улучшите «Кто твой папочка?» программу, добавив возможность выбора, которая позволяет пользователю
# введите имя и верните дедушку. Ваша программа по-прежнему должна использовать только
# один словарь пар сын-отец. Обязательно включите несколько
# поколения в вашем словаре, чтобы можно было найти совпадение.

sf = {'том круз':'эньони хопкинс', 'борис беккер':'тин тин', 'тин тин':'колин диэн',
      'сэм поттс':'симон поттс', 'симон поттс':'дэвид поттс'}
son = ''
father = ''
choice = None

while choice != "0":
    print("""\n\nВы хотите:

0 - Выйти
1 - View the Son-Father pairs
2 - Add a Son-Father pair
3 - Replace a Son-Father pair
4 - Delete a Son-Father pair
5 - Find a Grandfather
""")
    choice = input("Which option would you like to choose? ")
    if choice == "1":
        if sf == {}:
            print("\nThe database is empty right now, why don't you add some!")
            continue
        else:
            for son, father in sf.items():
                print(son.title(), "is", father.title(), "'s son.")
    elif choice == "2":
        son = input("\nWho is the son? ")
        son = son.lower()
        if son in sf:
            print("That son already exists! Try replacing the son instead.")
            continue
        father = input("Who is the father? ")
        father = father.lower()
        sf[son] = father
        print("\n", son.title(), "is", father.title(), "'s son.")
    elif choice == "3":
        sorf = input("\nDo you know the son or father?: ")
        sorf = sorf.lower()
        while sorf != "son" and sorf != "father":
            print("Sorry, please write 'son' or 'father'")
            sorf = input("Do you know the son or father?: ")
            sorf = sorf.lower()
        if sorf == "son":
            son = input("Who is the son? ")
            son = son.lower()
            if son in sf.keys():
                print("This current father is", sf[son].title())
                father = input("Who would you like to replace him with?: ")
                father = father.lower()
                sf[son] = father
                print("The father of", son.title(), "is now", father.title())
            elif son not in sf.keys():
                print("That son doesn't exist. Why don't you try adding him?")
                continue
        if sorf == "father":
            father = input("Who is the dad? ")
            father = father.lower()
            if father in sf.values():
                for son, dad in sf.items(): # find correct father in sf
                    if dad == father:
                        print("The current son is", son.title())
                        del sf[son]
                        son = input("Who would you like to replace him with?: ")
                        sf[son] = father
                        print(son.title(), " is ", father.title(), "'s son.")
                        break
            elif father not in sf.values():
                print(father, "doesn't exist as a father . Why don't you try adding him?")
    elif choice == "4":
        son = input("\nWho is the son? ")
        son = son.lower()
        if son not in sf.keys():
            print(son, "doesn't exist as a son! Perhaps you already deleted them.")
            continue
        else:
            print(son.title(), "and", sf[son].title(), "have been deleted.")
            del sf[son]
    elif choice == '5':
        son = input("\nWho is the grandson? ")
        son = son.lower()
        if son not in sf.keys():
            print(son.title(), "doesn't exist as a son! Why don't you try adding him?")
        else:
            dad = sf[son]
            if dad not in sf.keys():
                print("Although", son.title(), "is in our dictionary,",
                      dad.title(), "is not as a son \nwhich is needed to find"
                      " a grandpa! Why don't you add him?")
            else:
                print(sf[dad].title(), " is ", son.title(), "'s Grandad.", sep="")
    else:
        print("Sorry, that's not a valid choice.")

print("\nThanks for playing!")
input("\n\nPress enter to exit.")
